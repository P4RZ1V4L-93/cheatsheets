# %%
import pandas as pd

# %%
colours = pd.Series(['Red', 'Blue', 'Green'])
colours
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
car_type = pd.Series(['BMW', 'Ferrari', 'McLaren'])
car_type
# Out:
# 0        BMW
# 1    Ferrari
# 2    McLaren
# dtype: object

# %%
cars = pd.DataFrame({'Car Type' : car_type, 'Colours': colours})
cars
# Out:
#   Car Type Colours
# 0      BMW     Red
# 1  Ferrari    Blue
# 2  McLaren   Green

# %%
car_sales_DataFrame = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales.csv')

# %%
car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
cars.to_csv('Cars.csv')

# %%
cars.dtypes
# Out:
# Car Type    object
# Colours     object
# dtype: object

# %%
cars.describe()
# Out:
#        Car Type Colours
# count         3       3
# unique        3       3
# top         BMW     Red
# freq          1       1

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Car Type  3 non-null      object
#  1   Colours   3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
mean_num = pd.Series([1, 5, 6, 8, 10])
mean_num.mean()
# Out:
# 6.0

# %%
sum_num = pd.Series([3, 5, 7, 10, 6])
sum_num.sum()
# Out:
# 31

# %%
car_sales_DataFrame.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales_DataFrame.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales_DataFrame.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales_DataFrame.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales_DataFrame.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales_DataFrame.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales_DataFrame.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales_DataFrame['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales_DataFrame['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_sales_DataFrame[car_sales_DataFrame['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales_DataFrame['Make'], car_sales_DataFrame['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales_DataFrame.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales_DataFrame['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales_DataFrame['Price'].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_316/865428699.py in <module>
# ----> 1 car_sales_DataFrame['Price'].plot()
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
car_sales_DataFrame["Price"] = car_sales_DataFrame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# Out:
# C:\Users\rahul\AppData\Local\Temp/ipykernel_316/1760639775.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales_DataFrame["Price"] = car_sales_DataFrame["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales_DataFrame['Make'] = car_sales_DataFrame['Make'].str.lower()
car_sales_DataFrame
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  toyota  White         150043      4   4000
# 1   honda    Red          87899      4   5000
# 2  toyota   Blue          32549      3   7000
# 3     bmw  Black          11179      5  22000
# 4  nissan  White         213095      4   3500
# 5  toyota  Green          99213      4   4500
# 6   honda   Blue          45698      4   7500
# 7   honda   Blue          54738      4   7000
# 8  toyota  White          60000      4   6250
# 9  nissan  White          31600      4   9700

# %%
car_sales_missing = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace = True)
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing["seats"] = 5
car_sales_missing
# Out:
# C:\Users\rahul\AppData\Local\Temp/ipykernel_316/2444412672.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_sales_missing["seats"] = 5
#      Make Colour       Odometer  Doors    Price  Seats  seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5      5

# %%
car_sales_missing['seats'].drop()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_316/486175675.py in <module>
# ----> 1 car_sales_missing['seats'].drop()
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4677         dtype: float64
#    4678         """
# -> 4679         return super().drop(
#    4680             labels=labels,
#    4681             axis=axis,
#
# ~\Desktop\sample_project_1\env\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
car_sales_missing=car_sales_missing.drop('seats', axis =1)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
car_sales_missing['Engine Size'] = [1.5, 2.3, 4.3, 2.6, 3.8, 3.3]

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.5
# 1   Honda    Red   87899.000000    4.0   $5,000      5          2.3
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          4.3
# 3     BMW  Black   11179.000000    5.0  $22,000      5          2.6
# 4  Nissan  White  213095.000000    4.0   $3,500      5          3.8
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          3.3

# %%
car_sales_missing["Price"] = car_sales_missing["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# Out:
# C:\Users\rahul\AppData\Local\Temp/ipykernel_316/1688503024.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales_missing["Price"] = car_sales_missing["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)

# %%
car_sales_missing['Price Per KM'] = car_sales_missing['Price'] / car_sales_missing['Odometer']

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   4000      5          1.5
# 1   Honda    Red   87899.000000    4.0   5000      5          2.3
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.3
# 3     BMW  Black   11179.000000    5.0  22000      5          2.6
# 4  Nissan  White  213095.000000    4.0   3500      5          3.8
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.3
#
#    Price Per KM
# 0      0.026659
# 1      0.056883
# 2      0.075837
# 3      1.967976
# 4      0.016425
# 5      0.048753

# %%
car_sales_missing=car_sales_missing.drop('Price Per KM', 1)
# Out:
# C:\Users\rahul\AppData\Local\Temp/ipykernel_316/357037094.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   car_sales_missing=car_sales_missing.drop('Price Per KM', 1)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.5
# 1   Honda    Red   87899.000000    4.0   5000      5          2.3
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.3
# 3     BMW  Black   11179.000000    5.0  22000      5          2.6
# 4  Nissan  White  213095.000000    4.0   3500      5          3.8
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.3

# %%
car_sales_missing=car_sales_missing.sample(frac = 1)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 1   Honda    Red   87899.000000    4.0   5000      5          2.3
# 3     BMW  Black   11179.000000    5.0  22000      5          2.6
# 0  Toyota  White  150043.000000    4.0   4000      5          1.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.8
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.3
# 2  Toyota   Blue   92302.666667    3.0   7000      5          4.3

# %%
car_sales_missing.reset_index(inplace = True, drop= True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0   Honda    Red   87899.000000    4.0   5000      5          2.3
# 1     BMW  Black   11179.000000    5.0  22000      5          2.6
# 2  Toyota  White  150043.000000    4.0   4000      5          1.5
# 3  Nissan  White  213095.000000    4.0   3500      5          3.8
# 4  Toyota  Green   92302.666667    4.0   4500      5          3.3
# 5  Toyota   Blue   92302.666667    3.0   7000      5          4.3

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].apply(lambda x : x /1.6)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0   Honda    Red   54936.875000    4.0   5000      5          2.3
# 1     BMW  Black    6986.875000    5.0  22000      5          2.6
# 2  Toyota  White   93776.875000    4.0   4000      5          1.5
# 3  Nissan  White  133184.375000    4.0   3500      5          3.8
# 4  Toyota  Green   57689.166667    4.0   4500      5          3.3
# 5  Toyota   Blue   57689.166667    3.0   7000      5          4.3

# %%
car_sales_missing.rename(columns={"Odometer": "Odometer (Miles)"}, inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Engine Size
# 0   Honda    Red      54936.875000    4.0   5000      5          2.3
# 1     BMW  Black       6986.875000    5.0  22000      5          2.6
# 2  Toyota  White      93776.875000    4.0   4000      5          1.5
# 3  Nissan  White     133184.375000    4.0   3500      5          3.8
# 4  Toyota  Green      57689.166667    4.0   4500      5          3.3
# 5  Toyota   Blue      57689.166667    3.0   7000      5          4.3
